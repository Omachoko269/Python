# %%
import pandas as pd
import numpy as np

# %%
# path of data 
path = 'https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DA0101EN/automobileEDA.csv'
df = pd.read_csv(path)
df.head().T
# Out:
#                              0            1            2         3         4
# symboling                    3            3            1         2         2
# normalized-losses          122          122          122       164       164
# make               alfa-romero  alfa-romero  alfa-romero      audi      audi
# aspiration                 std          std          std       std       std
# num-of-doors               two          two          two      four      four
# body-style         convertible  convertible    hatchback     sedan     sedan
# drive-wheels               rwd          rwd          rwd       fwd       4wd
# engine-location          front        front        front     front     front
# wheel-base                88.6         88.6         94.5      99.8      99.4
# length                0.811148     0.811148     0.822681   0.84863   0.84863
# width                 0.890278     0.890278     0.909722  0.919444  0.922222
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201 entries, 0 to 200
# Data columns (total 29 columns):
# symboling            201 non-null int64
# normalized-losses    201 non-null int64
# make                 201 non-null object
# aspiration           201 non-null object
# num-of-doors         201 non-null object
# body-style           201 non-null object
# drive-wheels         201 non-null object
# engine-location      201 non-null object
# wheel-base           201 non-null float64
# length               201 non-null float64
# width                201 non-null float64
# height               201 non-null float64
# curb-weight          201 non-null int64
# engine-type          201 non-null object
# num-of-cylinders     201 non-null object
# engine-size          201 non-null int64
# fuel-system          201 non-null object
# bore                 201 non-null float64
# stroke               197 non-null float64
# compression-ratio    201 non-null float64
# ...

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()
lr
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
list_ = lambda df : print(list(df.columns))

# %%
list_(df)
# Out:
# ['symboling', 'normalized-losses', 'make', 'aspiration', 'num-of-doors', 'body-style', 'drive-wheels', 'engine-location', 'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type', 'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke', 'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg', 'highway-mpg', 'price', 'city-L/100km', 'horsepower-binned', 'diesel', 'gas']

# %%
X = df[['highway-mpg']] # independent variable
Y = df['price'] # dependent variable

# %%
lr.fit(X,Y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
Yhat=lr.predict(X)

# %%
len(Yhat[0:5])
# Out:
# 5

# %%
print(list(Yhat[0:5]))
# Out:
# [16236.504643465414, 16236.504643465414, 17058.23802178734, 13771.304508499634, 20345.171535075042]

# %%
Yhat[4]
# Out:
# 20345.171535075042

# %%
len(X), len(Y)
# Out:
# (201, 201)

# %%
lr.intercept_
# Out:
# 38423.305858157415

# %%
lr.coef_
# Out:
# array([-821.73337832])

# %%
lm1 = LinearRegression()
lm1
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
list_ = lambda df : print(list(df.columns))

# %%
lm1.fit(X,Y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
list_(df)
# Out:
# ['symboling', 'normalized-losses', 'make', 'aspiration', 'num-of-doors', 'body-style', 'drive-wheels', 'engine-location', 'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type', 'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke', 'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg', 'highway-mpg', 'price', 'city-L/100km', 'horsepower-binned', 'diesel', 'gas']

# %%
Q = df[['engine-size']] # independent variable
W = df['price'] # dependent variable

# %%
lm1.fit(Q, W)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
What=lm1.predict(Q)

# %%
len(What[0:5])
# Out:
# 5

# %%
print(list(What[0:10]))
# Out:
# [13728.463133603032, 13728.463133603032, 17399.383478814183, 10224.402804083296, 14729.623227751526, 14729.623227751526, 14729.623227751526, 14729.623227751526, 13895.323149294447, 10057.542788391882]

# %%
What[8]
# Out:
# 13895.323149294447

# %%
len(Q), len(W)
# Out:
# (201, 201)

# %%
lm1.coef_
# Out:
# array([166.86001569])

# %%
lm1.intercept_
# Out:
# -7963.338906281042

# %%
What=38423.31-821.733*Q

# %%
#continue from multiple linear regression

# %%
# list_(df)

# %%
var = ['horsepower', 'curb-weight', 'engine-size', 'highway-mpg']
Z = df[var]

# %%
#list_(Z)

# %%
Z.sample(5), Z.head(), Z.tail()
# Out:
# (     horsepower  curb-weight  engine-size  highway-mpg
#  125       207.0         2800          194           25
#  21         68.0         1876           90           38
#  133       160.0         2847          121           26
#  51         68.0         1950           91           38
#  159        70.0         2169           98           34,
#     horsepower  curb-weight  engine-size  highway-mpg
#  0       111.0         2548          130           27
#  1       111.0         2548          130           27
#  2       154.0         2823          152           26
#  3       102.0         2337          109           30
#  4       115.0         2824          136           22,
#       horsepower  curb-weight  engine-size  highway-mpg
#  196       114.0         2952          141           28
#  197       160.0         3049          141           25
#  198       134.0         3012          173           23
#  199       106.0         3217          145           27
# ...

# %%
lr.fit(Z, df['price'])
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
lr.intercept_
# Out:
# -15806.624626329234

# %%
lr.coef_
# Out:
# array([53.49574423,  4.70770099, 81.53026382, 36.05748882])

# %%
print(f'a: {lr.intercept_}')

for x in range(4):
    print(f'b_{x+1}: {lr.coef_[x]} ')
# Out:
# a: -15806.624626329234
# b_1: 53.49574422604913
# b_2: 4.707700994613944
# b_3: 81.53026382122763
# b_4: 36.057488816485936

# %%
#quiz 2 create and train a model

lm2 = LinearRegression()
lm2.fit(df[['normalized-losses' , 'highway-mpg']],df['price'])
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
lm2.coef_
# Out:
# array([   1.49789586, -820.45434016])

# %%
lm2.intercept_
# Out:
# 38201.31327245728

# %%
# import the visualization packages
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201 entries, 0 to 200
# Data columns (total 29 columns):
# symboling            201 non-null int64
# normalized-losses    201 non-null int64
# make                 201 non-null object
# aspiration           201 non-null object
# num-of-doors         201 non-null object
# body-style           201 non-null object
# drive-wheels         201 non-null object
# engine-location      201 non-null object
# wheel-base           201 non-null float64
# length               201 non-null float64
# width                201 non-null float64
# height               201 non-null float64
# curb-weight          201 non-null int64
# engine-type          201 non-null object
# num-of-cylinders     201 non-null object
# engine-size          201 non-null int64
# fuel-system          201 non-null object
# bore                 201 non-null float64
# stroke               197 non-null float64
# compression-ratio    201 non-null float64
# ...

# %%
w = 12 # width
h = 10 # height
plt.figure(figsize=(w, h))
sns.regplot(x="highway-mpg", y="price", data=df)
plt.ylim(0,)
# Out:
# C:\Users\Choko Armani\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# (0, 48281.689838361526)

# %%
w = 12 # width
h = 10 # height
plt.figure(figsize=(w, h))
sns.regplot(x="highway-mpg", y="price", data=df)
plt.ylim(0,)
# Out:
# C:\Users\Choko Armani\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# (0, 48300.09583554664)

# %%
plt.figure(figsize=(w, h))
sns.regplot(x="peak-rpm", y="price", data=df)
plt.ylim(0,)
# Out:
# C:\Users\Choko Armani\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# (0, 47422.919330307624)

# %%
plt.figure(figsize=(w, h))
sns.regplot(x="peak-rpm", y="price", data=df)
plt.ylim(0,)
# Out:
# C:\Users\Choko Armani\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# (0, 47422.919330307624)

# %%
#The variable "peak-rpm" has a stronger correlation with "price", it is approximate -0.704692  compared to   "highway-mpg" which is approximate     -0.101616. You can verify it using the following command:
df[["peak-rpm","highway-mpg","price"]].corr()
# Out:
#              peak-rpm  highway-mpg     price
# peak-rpm     1.000000    -0.058598 -0.101616
# highway-mpg -0.058598     1.000000 -0.704692
# price       -0.101616    -0.704692  1.000000

# %%
#residual plot
w = 12
h = 10
plt.figure(figsize=(w, h))
sns.residplot(df['highway-mpg'], df['price'])
plt.show()

# %%
w = 12
h = 10
plt.figure(figsize=(w, h))
sns.residplot(df['highway-mpg'], df['price'])
plt.show()

# %%
#What is this plot telling us?

#We can see from this residual plot that the residuals are not randomly spread around the x-axis, which leads us to believe that maybe a non-linear model is more appropriate for this data.

# %%
Y_hat = lr.predict(Z)

# %%
plt.figure(figsize=(w, h))


ax1 = sns.distplot(df['price'], hist=False, color="r", label="Actual Value")
sns.distplot(Yhat, hist=False, color="g", label="Fitted Values" , ax=ax1)


plt.title('Actual vs Fitted Values for Price')
plt.xlabel('Price (in dollars)')
plt.ylabel('Proportion of Cars')

plt.show()
plt.close()
# Out:
# C:\Users\Choko Armani\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# C:\Users\Choko Armani\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
#polyminial regression and pipepines

def PlotPolly(model, independent_variable, dependent_variabble, Name):
    x_new = np.linspace(15, 55, 100)
    y_new = model(x_new)

    plt.plot(independent_variable, dependent_variabble, '.', x_new, y_new, '-')
    plt.title('Polynomial Fit with Matplotlib for Price ~ Length')
    ax = plt.gca()
    ax.set_facecolor((0.898, 0.898, 0.898))
    fig = plt.gcf()
    plt.xlabel(Name)
    plt.ylabel('Price of Cars')

    plt.show()
    plt.close()

# %%
x = df['highway-mpg']
y = df['price']

# %%
# Here we use a polynomial of the 3rd order (cubic) 
f = np.polyfit(x, y, 3)
p = np.poly1d(f)
print(p)
# Out:
#         3         2
# -1.557 x + 204.8 x - 8965 x + 1.379e+05

# %%
PlotPolly(p, x, y, 'highway-mpg')

# %%
# calculate polynomial
# Here we use a polynomial of the 3rd order (cubic) 
f1 = np.polyfit(x, y, 11)
p1 = np.poly1d(f1)
print(p)
PlotPolly(p1,x,y, 'Length')
# Out:
#         3         2
# -1.557 x + 204.8 x - 8965 x + 1.379e+05

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
pr = PolynomialFeatures(degree=2)
pr
# Out:
# PolynomialFeatures(degree=2, include_bias=True, interaction_only=False)

# %%
Z_pr = pr.fit_transform(Z)

# %%
Z.shape
# Out:
# (201, 4)

# %%
Z_pr.shape
# Out:
# (201, 15)

# %%
#Pipeline

from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

# %%
Input=[('scale',StandardScaler()), ('polynomial', PolynomialFeatures(include_bias=False)), ('model',LinearRegression())]

# %%
pipe=Pipeline(Input)
pipe
# Out:
# Pipeline(memory=None,
#      steps=[('scale', StandardScaler(copy=True, with_mean=True, with_std=True)), ('polynomial', PolynomialFeatures(degree=2, include_bias=False, interaction_only=False)), ('model', LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False))])

# %%
pipe.fit(Z,y)
# Out:
# Pipeline(memory=None,
#      steps=[('scale', StandardScaler(copy=True, with_mean=True, with_std=True)), ('polynomial', PolynomialFeatures(degree=2, include_bias=False, interaction_only=False)), ('model', LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False))])

# %%
ypipe=pipe.predict(Z)
ypipe[0:4]
# Out:
# array([13102.74784201, 13102.74784201, 18225.54572197, 10390.29636555])

# %%
#quiz 5 Create a pipeline that Standardizes the data, then perform prediction using a linear regression model using the features Z and targets y

Input=[('scale',StandardScaler()),('model',LinearRegression())]

pipe=Pipeline(Input)

pipe.fit(Z,y)

ypipe=pipe.predict(Z)
ypipe[0:10]
# Out:
# array([13699.11161184, 13699.11161184, 19051.65470233, 10620.36193015,
#        15521.31420211, 13869.66673213, 15456.16196732, 15974.00907672,
#        17612.35917161, 10722.32509097])

# %%
#continue from part 4 measures for in sample Evaluation
